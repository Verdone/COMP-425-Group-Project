# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 40.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
python -m pip install ultralytics
# Out:
#   File "<ipython-input-1-23176a6e8aed>", line 1
#     python -m pip install ultralytics
#               ^
# SyntaxError: invalid syntax

# %%
from google.colab import drive
drive.mount('/content/drive')

#!unzip /content/Copy_of_ve_con.zip -d /content/container
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
#shutil.copy("/content/drive/MyDrive/Colab_Notebooks/yolo/container_2/ocr_container.zip", "/content")
shutil.copy("/content/drive/MyDrive/Colab_Notebooks/yolo/container_2/ocr_container_colored.zip", "/content")
# Out:
# '/content/ocr_container_colored.zip'

# %%
# !unzip /content/ocr_container_colored.zip -d /content/
# Out:
# Archive:  /content/ocr_container_colored.zip
#    creating: /content/ocr_container_colored/
#    creating: /content/ocr_container_colored/test/
#    creating: /content/ocr_container_colored/test/images/
#   inflating: /content/ocr_container_colored/test/images/1446.jpg
#   inflating: /content/ocr_container_colored/test/images/1447.jpg
#   inflating: /content/ocr_container_colored/test/images/1450.jpg
#   inflating: /content/ocr_container_colored/test/images/1451.jpg
#   inflating: /content/ocr_container_colored/test/images/1454.jpg
#   inflating: /content/ocr_container_colored/test/images/1455.jpg
#   inflating: /content/ocr_container_colored/test/images/1457.jpg
#   inflating: /content/ocr_container_colored/test/images/1458.jpg
#   inflating: /content/ocr_container_colored/test/images/1460.jpg
#   inflating: /content/ocr_container_colored/test/images/1466.jpg
#   inflating: /content/ocr_container_colored/test/images/1467.jpg
# ...

# %%
# import locale
# def getpreferredencoding(do_setlocale = True):
#     return "UTF-8"
# locale.getpreferredencoding = getpreferredencoding

# %%
#!unzip /content/ocr_container.zip -d /content/
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
#model = YOLO("yolov9c.pt")
#model = YOLO("/content/drive/MyDrive/Colab_Notebooks/ocr_models/train/weights/last.pt")
model = YOLO("/content/drive/MyDrive/Colab_Notebooks/ocr_models_colored/train2/weights/last.pt")

# %%
#data_path=r"/content/drive/MyDrive/Colab_Notebooks/yolo/container_2/data.yaml"
#data_path=r"/content/ocr_container/data.yaml"
#project_path=r'/content/drive/MyDrive/Colab_Notebooks/ocr_models'
data_path=r"/content/ocr_container_colored/data.yaml"
project_path=r'/content/drive/MyDrive/Colab_Notebooks/ocr_models_colored'

# %%
train_results=model.train(
    data=data_path,
    epochs=400,
    device=0,
    batch=-1,
    save_period=50,
    project=project_path,
    cache=True,
    workers=8,
    resume=True,
)
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Out:
# '/content/Copy_of_ve_con.zip'

# %%
cd /content/
# Out:
# /content

# %%
model = YOLO("/content/drive/MyDrive/Colab_Notebooks/ocr_models_colored/train2/weights/best.pt")

# %%
result = model(r"/content/ocr_container_colored/val/images/1448.jpg")


result=result[0]
boxes = result.boxes  # Boxes object for bounding box outputs
masks = result.masks  # Masks object for segmentation masks outputs
keypoints = result.keypoints  # Keypoints object for pose outputs
probs = result.probs  # Probs object for classification outputs
obb = result.obb  # Oriented boxes object for OBB outputs
result.show()  # display to screen
# Out:
# image 1/1 /content/ocr_container_colored/val/images/1448.jpg: 384x640 2 Os, 1 V, 1 Z, 1 1, 1 3, 1 7, 55.3ms
# Speed: 10.6ms preprocess, 55.3ms inference, 313.5ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=153x91>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/drive/MyDrive/Colab_Notebooks/ocr_models_colored/train2/weights/best.pt")

# Customize validation settings
validation_results = model.val(
    data=data_path,
    imgsz=640, batch=16, conf=0.25, iou=0.6, device="0",
    save_dir=project_path)
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv9c summary (fused): 156 layers, 25,347,004 parameters, 0 gradients, 102.5 GFLOPs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-a0efaad27688> in <cell line: 0>()
#       5
#       6 # Customize validation settings
# ----> 7 validation_results = model.val(
#       8     data=data_path,
#       9     imgsz=640, batch=16, conf=0.25, iou=0.6, device="0",
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in val(self, validator, **kwargs)
#     626
#     627         validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 628         validator(model=self.model)
#     629         self.metrics = validator.metrics
#     630         return validator.metrics
#
# ...

# %%
# from google.colab import files
# files.download('example.txt')

# %%
# !zip -r /content/runs/detect/val.zip /content/runs/detect/val
# Out:
#   adding: content/runs/detect/val/ (stored 0%)
#   adding: content/runs/detect/val/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/detect/val/val_batch0_pred.jpg (deflated 6%)
#   adding: content/runs/detect/val/R_curve.png (deflated 18%)
#   adding: content/runs/detect/val/confusion_matrix_normalized.png (deflated 35%)
#   adding: content/runs/detect/val/val_batch0_labels.jpg (deflated 7%)
#   adding: content/runs/detect/val/val_batch2_pred.jpg (deflated 7%)
#   adding: content/runs/detect/val/PR_curve.png (deflated 24%)
#   adding: content/runs/detect/val/val_batch2_labels.jpg (deflated 7%)
#   adding: content/runs/detect/val/confusion_matrix.png (deflated 35%)
#   adding: content/runs/detect/val/val_batch1_labels.jpg (deflated 7%)
#   adding: content/runs/detect/val/F1_curve.png (deflated 18%)
#   adding: content/runs/detect/val/P_curve.png (deflated 28%)

# %%
from google.colab import files
files.download("/content/runs/detect/val.zip")

# %%
model = YOLO("/content/drive/MyDrive/Colab_Notebooks/train4/weights/best.pt")
validation_results = model.val(
    data=r'/content/container/data.yaml',
    imgsz=640, batch=16, conf=0.25, iou=0.6, device="0",
    save_dir="./")
